# %%
import os
import sys

from genophenocorr import *

# %%
allKBGPatients = Cohort('phenopackets/*.json', ref = 'hg19')
# Out:
# INFO:pyensembl.sequence_data:Loaded sequence dictionary from /Users/rekerl/Library/Caches/pyensembl/GRCh37/ensembl75/Homo_sapiens.GRCh37.75.cdna.all.fa.gz.pickle
# INFO:pyensembl.sequence_data:Loaded sequence dictionary from /Users/rekerl/Library/Caches/pyensembl/GRCh37/ensembl75/Homo_sapiens.GRCh37.75.ncrna.fa.gz.pickle
# INFO:pyensembl.sequence_data:Loaded sequence dictionary from /Users/rekerl/Library/Caches/pyensembl/GRCh37/ensembl75/Homo_sapiens.GRCh37.75.pep.all.fa.gz.pickle

# %%
allKBGPatients.get_cohort_description_df()
# Out:
#                   Patient ID      Disease       Gene  \
# 0         Goldenberg2016_P13         None         {}
# 1           Low, 2016_P9 (1)  OMIM:148050  {ANKRD11}
# 2           VanDongen2019_P2  OMIM:148050  {ANKRD11}
# 3         Low, 2016_P29 (27)  OMIM:148050  {ANKRD11}
# 4           Ockeloen2015_P20         None         {}
# ..                       ...          ...        ...
# 335  Murray, 2017_P13 (11.1)  OMIM:148050  {ANKRD11}
# 336         Ockeloen2015_P19  OMIM:148050  {ANKRD11}
# 337         Gnazzo, 2020_P10  OMIM:148050  {ANKRD11}
# 338                    KBG15  OMIM:148050  {ANKRD11}
# 339      Srivastava, 2017_P1         None         {}
#
#                                     Variant            Protein  \
# 0                                        {}                 {}
# 1       {chr16 g.89350538_89350542delTTTTT}  {ENSP00000301030}
# 2                     {chr16 g.89341328C>G}  {ENSP00000301030}
# 3                     {chr16 g.89351149G>A}  {ENSP00000301030}
# ...

# %%
tempPat = allKBGPatients.all_patients_d.get('KBG1')
tempPat.get_patient_description_df()
# Out:
# ID                                                                KBG1
# Disease ID                                                        None
# Disease Label                                                     None
# HPO IDs              ['HP:0001511', 'HP:0001627', 'HP:0001270', 'HP...
# HPO Terms            ['Intrauterine growth retardation', 'Abnormal ...
# Variant                                                             []
# Variant Type                                                        []
# Gene Affected                                                       []
# Gene ID                                                             []
# Effect of Variant                                                   []
# Transcript ID                                                       []
# Protein Affected                                                    []
# Protein ID                                                          []
# dtype: object
