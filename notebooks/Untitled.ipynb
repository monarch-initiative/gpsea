# %% [markdown]
# <H1>Comparing different variant types</H1>
# <p>Todo explain missense vs nonsense as example etc. </p>
# <p>This notebook demonstrates how to compare missense vs nonsenes ... </p>

# %%
import os
import sys

#sys.path.insert(0, os.path.abspath('../genophenocorr'))
from genophenocorr import *

# %% [markdown]
# <H2>Data import</H2>
# <p>genophenocorr takes a collection of phenopackets as its input. In general, the phenopackets should represent individuals of a cohort to be investigated. For instance, we might use genophenocorr to investigate a cohort of 100 individuals with Marfan syndrome as to whether missense or nonsense variants are associated with different clinical manifestations of this disease. Therefore, the first step to use genophenocorr is to obtain or generate the phenopackets. This step is outside of the scope of the genophenocorr library, but can be done with tools such as ...(Peter to complete).</p>
# <p>For our example, we ingest phenopackets from the </p>

# %%
allPatients = AllPatients('../phenopackets/PlatzerData/*.json')
# Out:
# INFO:pyensembl.sequence_data:Loaded sequence dictionary from /Users/robinp/Library/Caches/pyensembl/GRCh38/ensembl107/Homo_sapiens.GRCh38.cdna.all.fa.gz.pickle
# INFO:pyensembl.sequence_data:Loaded sequence dictionary from /Users/robinp/Library/Caches/pyensembl/GRCh38/ensembl107/Homo_sapiens.GRCh38.ncrna.fa.gz.pickle
# INFO:pyensembl.sequence_data:Loaded sequence dictionary from /Users/robinp/Library/Caches/pyensembl/GRCh38/ensembl107/Homo_sapiens.GRCh38.pep.all.fa.gz.pickle

# %% [markdown]
# <h2>Preview</h2>
# <p>The following optional step allows users to inspect the contents of the ingested phenopackets.</p>

# %%
[p.describe() for p in allPatients.all_patients.values()]
# Out:
# [{'ID': 'Individual 5',
#   'Disease': None,
#   'Phenotypic Features': ['Motor delay',
#    'Persistent head lag',
#    'Delayed ability to sit',
#    'Delayed ability to walk',
#    'Intellectual disability, severe',
#    'Autistic behavior',
#    'Absent speech',
#    'Spastic diplegia',
#    'Infantile muscular hypotonia',
#    'Cerebral atrophy',
#    'Delayed CNS myelination',
#    'Round face',
#    'Prominent nasal bridge',
#    'Thin upper lip vermilion',
#    'Upslanted palpebral fissure',
#    'Short philtrum',
#    'Anteverted nares',
#    'Thick eyebrow'],
#   'Variant': 'chr16 g.1767834C>T',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1767834, ref='C', alt='T', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.R1154C),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '12',
#   'Disease': None,
#   'Phenotypic Features': ['Spasticity',
#    'Cerebral palsy',
#    'Intellectual disability, severe'],
#   'Variant': 'chr16 g.1767834C>T',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1767834, ref='C', alt='T', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.R1154C),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '2',
#   'Disease': None,
#   'Phenotypic Features': ['Ataxia', 'Intellectual disability, severe'],
#   'Variant': 'chr16 g.1706418G>T',
#   'Top effect of Variant': PrematureStop(variant=Variant(contig='16', start=1706418, ref='G', alt='T', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.E27*),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '3',
#   'Disease': None,
#   'Phenotypic Features': ['Intellectual disability, moderate'],
#   'Variant': 'chr16 g.1706450C>G',
#   'Top effect of Variant': PrematureStop(variant=Variant(contig='16', start=1706450, ref='C', alt='G', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.Y37*),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '13',
#   'Disease': None,
#   'Phenotypic Features': ['Unsteady gait',
#    'Oromotor apraxia',
#    'Poor coordination',
#    'Intellectual disability, moderate'],
#   'Variant': 'chr16 g.1767834C>T',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1767834, ref='C', alt='T', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.R1154C),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': 'Individual 4',
#   'Disease': None,
#   'Phenotypic Features': ['Motor delay',
#    'Persistent head lag',
#    'Delayed ability to roll over',
#    'Delayed ability to sit',
#    'Delayed ability to walk',
#    'Intellectual disability, severe',
#    'Autistic behavior',
#    'Absent speech',
#    'Delayed gross motor development',
#    'Infantile muscular hypotonia',
#    'Cerebral atrophy',
#    'Round face',
#    'Prominent nasal bridge',
#    'Thin upper lip vermilion',
#    'Short stature'],
#   'Variant': 'chr16 g.1767834C>T',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1767834, ref='C', alt='T', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.R1154C),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '4',
#   'Disease': None,
#   'Phenotypic Features': ['Intellectual disability, mild'],
#   'Variant': 'chr16 g.1748705G>A',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1748705, ref='G', alt='A', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.G408R),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '8',
#   'Disease': None,
#   'Phenotypic Features': ['Spastic paraplegia',
#    'Intellectual disability, severe'],
#   'Variant': 'chr16 g.1762843C>T',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1762843, ref='C', alt='T', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.R586C),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': 'Individual 3',
#   'Disease': None,
#   'Phenotypic Features': ['Motor delay',
#    'Delayed ability to sit',
#    'Delayed ability to walk',
#    'Intellectual disability, profound',
#    'Delayed speech and language development',
#    'Spastic diplegia',
#    'Loss of ambulation',
#    'Seizure',
#    'Prominent nasal bridge',
#    'Thin upper lip vermilion',
#    'Short stature',
#    'Obesity'],
#   'Variant': 'chr16 g.1762843C>T',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1762843, ref='C', alt='T', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.R586C),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': 'Individual 2',
#   'Disease': None,
#   'Phenotypic Features': ['Motor delay',
#    'Delayed ability to roll over',
#    'Delayed ability to walk',
#    'Intellectual disability, severe',
#    'Delayed speech and language development',
#    'Spastic diplegia',
#    'Loss of ambulation',
#    'Seizure',
#    'Cerebral atrophy',
#    'Delayed CNS myelination',
#    'Round face',
#    'Thin upper lip vermilion',
#    'Short stature',
#    'Obesity',
#    'Precocious puberty'],
#   'Variant': 'chr16 g.1762843C>T',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1762843, ref='C', alt='T', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.R586C),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '9',
#   'Disease': None,
#   'Phenotypic Features': ['Lower limb muscle weakness',
#    'Upper motor neuron dysfunction',
#    'Spasticity',
#    'Intellectual disability, moderate'],
#   'Variant': 'chr16 g.1762843C>T',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1762843, ref='C', alt='T', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.R586C),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '5',
#   'Disease': None,
#   'Phenotypic Features': [],
#   'Variant': 'chr16 g.1760409T>C',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1760409, ref='T', alt='C', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.L452P),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '6',
#   'Disease': None,
#   'Phenotypic Features': ['Intellectual disability, mild'],
#   'Variant': 'chr16 g.1760409T>C',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1760409, ref='T', alt='C', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.L452P),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': 'Individual 1',
#   'Disease': None,
#   'Phenotypic Features': ['Motor delay',
#    'Delayed ability to walk',
#    'Intellectual disability, severe',
#    'Delayed speech and language development',
#    'Spastic diplegia',
#    'Loss of ambulation',
#    'Cerebral atrophy',
#    'Delayed CNS myelination',
#    'Round face',
#    'Thin upper lip vermilion',
#    'Short stature',
#    'Obesity',
#    'Precocious puberty'],
#   'Variant': 'chr16 g.1762843C>T',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1762843, ref='C', alt='T', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.R586C),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '7',
#   'Disease': None,
#   'Phenotypic Features': ['Intellectual disability, mild'],
#   'Variant': 'chr16 g.1762388G>A',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1762388, ref='G', alt='A', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.R533Q),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '10',
#   'Disease': None,
#   'Phenotypic Features': ['Intellectual disability, moderate'],
#   'Variant': 'chr16 g.1766768C>G',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1766768, ref='C', alt='G', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.H1002Q),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '11',
#   'Disease': None,
#   'Phenotypic Features': ['Spasticity', 'Intellectual disability, moderate'],
#   'Variant': 'chr16 g.1767834C>T',
#   'Top effect of Variant': Substitution(variant=Variant(contig='16', start=1767834, ref='C', alt='T', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.R1154C),
#   'Protein affected by Top Effect': 'ENSP00000501096'},
#  {'ID': '1',
#   'Disease': None,
#   'Phenotypic Features': ['Ataxia', 'Intellectual disability, moderate'],
#   'Variant': 'chr16 g.1706403_1706403delG',
#   'Top effect of Variant': FrameShift(variant=Variant(contig='16', start=1706403, ref='G', alt='', reference_name='GRCh38'), transcript_name=MAPK8IP3-217, transcript_id=ENST00000673691, effect_description=p.G22fs),
#   'Protein affected by Top Effect': 'ENSP00000501096'}]

# %% [markdown]
# <H2>etc</H2>
# <p>todo step by step to obtain output table with chi2 for missense vs nonses with explanations of the code</p>

# %% [markdown]
# <h2>Fianlly</h2>
# <p>Explain how to check for other vairnat and list all available vairant tuypes</p>
