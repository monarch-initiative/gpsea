# %%
import sys
import glob
 
sys.path.insert(0, '/Users/rekerl/Documents/Programs/gpc/')
 
from gpc import *
from gpc import compare
from gpc import genotype_class as GC

# %%
allPatients = AllPatients('../phenopackets/cohort/*.json')

# %%
compare.RunStats(allPatients, GC.is_deletion, GC.is_duplication)
# Out:
# Total hpo terms: 7
#            HP:0100023-Recurrent hand flapping  \
# counts
# 1 w/ hpo                            46.000000
# 1 w/o hpo                          112.000000
# 2 w/ hpo                            25.000000
# 2 w/o hpo                           58.000000
# pval                                 0.882655
#
#            HP:0100716-Self-injurious behavior  HP:0000733-Stereotypy  \
# counts
# 1 w/ hpo                            17.000000               36.00000
# 1 w/o hpo                          141.000000              122.00000
# 2 w/ hpo                            28.000000               30.00000
# 2 w/o hpo                           55.000000               53.00000
# pval                                 0.000041                0.03334
#
#            HP:0000723-Restrictive behavior  HP:0010529-Echolalia  \
# counts
# 1 w/ hpo                         44.000000             39.000000
# 1 w/o hpo                       114.000000            119.000000
# 2 w/ hpo                         33.000000             34.000000
# 2 w/o hpo                        50.000000             49.000000
# pval                              0.080622              0.011956
#
#            HP:4000069-Preoccupation with unusual objects  \
# counts
# 1 w/ hpo                                       64.000000
# 1 w/o hpo                                      94.000000
# 2 w/ hpo                                       39.000000
# 2 w/o hpo                                      44.000000
# pval                                            0.341302
#
#            HP:0012760-Impaired social reciprocity
# counts
# 1 w/ hpo                               136.000000
# 1 w/o hpo                               22.000000
# 2 w/ hpo                                74.000000
# 2 w/o hpo                                9.000000
# pval                                     0.549805
